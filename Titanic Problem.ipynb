# %%
1.Find out how many male and female passengers was onboarded
2.How many survived we have
3.How many casulaity we have
4.What is name of the person who is the eldest one
5.How many passenger do we have in first ,second and third class
6.How many person do we have whose name start with "s"
7.try to create a new column which is summation of "Sibsp" and "parch"
8.How many person do we have below age of 25
9.How many person died whose age was less than 40
10.From a cabin column seperate text and numeric value.
import pandas as pd
 # data set
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.head()
# 1.Find out how many male and female passengers was onboarded
len(df[df['Sex']=='male'])
len(df[df['Sex']=='female'])
# 2.How many survived we have
len(df[df['Survived']==1])
# 3.How many casulaity we have
len(df[df['Survived']==0])
# 4.What is name of the person who is the eldest one
df[df['Age']==max(df['Age'])]
df[df['Age']==max(df['Age'])]['Name']
# 5.How many passenger do we have in first ,second and third class

len(df[df['Pclass']==1]) # class 1
for i in range(1,4):
    count=len(df[df['Pclass']==i])
    print("class",i,"has",count)
# 6.How many person do we have whose name start with "s"

df['Name']
count=0
for i in df['Name']:
    if i[0]=='s' or i[0]=='S':
        count=count+1
print(count)        
# 7.try to create a new column which is summation of "Sibsp" and "parch"
df['summation']=df['SibSp'] + df['Parch']
df
# 8.How many person do we have below age of 25

df[df['Age']<25]
# 9.How many person died whose age was less than 40
df[(df['Age']<40) & (df['Survived']==1)]
# 10.From a cabin column seperate text and numeric value.
df['Cabin']
for i in df['cabin']:
    if i!=NaN:
        
df['numeric'] = df['Cabin'].str.extract('(\d+)')
df
df['text'] = df['Cabin'].str.extract('(\w)')
df
df.columns
